# %% [markdown]
# <a href="https://colab.research.google.com/github/Janikaasri/AI-LAB-EXPERIMENTS/blob/main/EX_NO_34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
monkey = "floor"
banana = "high"
box = "floor"

if monkey == "floor" and box == "floor":
    print("Monkey pushes the box under the banana.")
    box = "under banana"

if box == "under banana":
    print("Monkey climbs the box.")

if box == "under banana":
    print("Monkey gets the banana.")
