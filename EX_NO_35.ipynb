# %% [markdown]
# <a href="https://colab.research.google.com/github/Janikaasri/AI-LAB-EXPERIMENTS/blob/main/EX_NO_35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = {
    "apple": "red",
    "banana": "yellow",
    "orange": "orange",
    "grape": "purple",
    "mango": "yellow"
}

for fruit, color in fruits.items():
    print(fruit, "->", color)
# Out:
# apple -> red
# banana -> yellow
# orange -> orange
# grape -> purple
# mango -> yellow
