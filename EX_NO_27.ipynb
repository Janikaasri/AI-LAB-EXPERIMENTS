# %% [markdown]
# <a href="https://colab.research.google.com/github/Janikaasri/AI-LAB-EXPERIMENTS/blob/main/EX_NO_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
db = {
    "Ravi": "10-05-2002",
    "Anu": "15-08-2003",
    "Kumar": "20-01-2001",
    "Priya": "25-12-2002"
}

name = input("Enter name: ")

if name in db:
    print("DOB =", db[name])
else:
    print("Name not found")
