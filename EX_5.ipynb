# %% [markdown]
# <a href="https://colab.research.google.com/github/Janikaasri/AI-LAB-EXPERIMENTS/blob/main/EX_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nested List
nested_list = [[1, 2, 3],
               [4, 5, 6],
               [7, 8, 9]]

print("Nested List:", nested_list)


# Length of List
my_list = [1, 2, 3, 4, 5]

print("Length of List:", len(my_list))


# Concatenation of Lists
list1 = [1, 2, 3]
list2 = [4, 5, 6]

concatenated_list = list1 + list2

print("Concatenated List:", concatenated_list)


# Membership Check
my_list = [1, 2, 3, 4, 5]

if 3 in my_list:
    print("3 is in the list")
else:
    print("3 is not in the list")


# Iterating Through a List
my_list = [1, 2, 3, 4, 5]

for item in my_list:
    print(item)


# Indexing and Slicing
my_list = [1, 2, 3, 4, 5]

print("First element:", my_list[0])
print("Last element:", my_list[-1])
print("Sliced List:", my_list[1:4])
