# %% [markdown]
# <a href="https://colab.research.google.com/github/Janikaasri/AI-LAB-EXPERIMENTS/blob/main/EX_NO_40.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
html = """
<html>
<head>
    <title>My AI Blog</title>
</head>

<body>

    <h1>Welcome to My AI Blog</h1>

    <p>This is my simple web blog created using Python.</p>

    <h2>Artificial Intelligence</h2>

    <p>Artificial Intelligence helps computers perform intelligent tasks.</p>

    <a href="https://www.google.com">Visit Google</a>

    <br><br>

    <img src="https://via.placeholder.com/300" width="300">

</body>
</html>
"""

file = open("blog.html", "w")
file.write(html)
file.close()

print("Web blog created successfully!")
